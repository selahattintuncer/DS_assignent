# %% [markdown]
# # WITH PANDAS AND MATPLOTLIB

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# INSTRUCTIONS
#
# 1. Number of people by gender
# 1. Kill weapon
# 1. Age of killed people
# 1. Race of killed people
# 1. Killed People According to Races (Pie Chart)
# 1. Most common 15 Name or Surname of killed people
#
# <br>

# %% [markdown]
# read data
#
# if didn't work you can use this parameters: encoding="windows-1252"

# %%
df = pd.read_csv("data/PoliceKillingsUS.csv")

# %%
df.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False

# %% [markdown]
# ## 1: Plot number of people by gender

# %%
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
gender_dist = df["gender"].value_counts()

# %%
type(gender_dist)
# Out:
# pandas.core.series.Series

# %%
gender_dist
# Out:
# M    2428
# F     107
# Name: gender, dtype: int64

# %%
gender_dist.index
# Out:
# Index(['M', 'F'], dtype='object')

# %%
gender_dist.plot.bar(title= "Gender Distribution");
for index, value in enumerate(gender_dist.values):
    plt.text(index, value, str(value), ha = "center")

# %%
# with matplotlib_my
fig, ax = plt.subplots()
plt.bar(gender_dist.index, gender_dist.values);
plt.title("Gender Distribution")

for index, value in enumerate(gender_dist.values):
    plt.text(index, value, str(value), ha = "center")
    
plt.show()

# %%
# with matplotlib

# %% [markdown]
# ## 2: Plot 7 most common kill weapons

# %%
df["armed"].value_counts()[0:7]
# Out:
# gun             1398
# knife            373
# vehicle          177
# unarmed          171
# undetermined     117
# toy weapon       104
# machete           18
# Name: armed, dtype: int64

# %%
# Out:
# gun               1398
# knife              373
# vehicle            177
# unarmed            171
# undetermined       117
# toy weapon         104
# unknown weapon      18
# Name: armed, dtype: int64

# %%
# with pandas _ my
mckw = df["armed"].value_counts()[0:7]
mckw.plot.bar(figsize=(8,5));
for index, value in enumerate(mckw.values):
    plt.text(index, value, str(value), ha = "center")
plt.xticks(rotation=60)
plt.show()

# %%
# with pandas
fig, ax = plt.subplots(figsize=(8,5))
plt.bar(mckw.index, mckw.values);
for index, value in enumerate(mckw.values):
    plt.text(index, value, str(value), ha = "center")
plt.xticks(rotation=60)

plt.show()

# %%
# with matplotlib

# %% [markdown]
# ## 3: Plot number of age of killed people under two groups : Under 25 and Above 25

# %%
# Out:
#    id                name      date  ... threat_level         flee  body_camera
# 0   3          Tim Elliot  02/01/15  ...       attack  Not fleeing        False
# 1   4    Lewis Lee Lembke  02/01/15  ...       attack  Not fleeing        False
# 2   5  John Paul Quintero  03/01/15  ...        other  Not fleeing        False
# 3   8     Matthew Hoffman  04/01/15  ...       attack  Not fleeing        False
# 4   9   Michael Rodriguez  04/01/15  ...       attack  Not fleeing        False
#
# [5 rows x 14 columns]

# %%
def age_cat(age):
    if age > 25.0:
        return "above25"
    else:
        return "below25"

# %%
df["age_cat"] = df["age"].apply(age_cat)
df.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  age_cat
# 0  Not fleeing        False  above25
# 1  Not fleeing        False  above25
# 2  Not fleeing        False  below25
# 3  Not fleeing        False  above25
# 4  Not fleeing        False  above25

# %%
# Out:
#    id                name      date  ...         flee body_camera  age_cat
# 0   3          Tim Elliot  02/01/15  ...  Not fleeing       False  above25
# 1   4    Lewis Lee Lembke  02/01/15  ...  Not fleeing       False  above25
# 2   5  John Paul Quintero  03/01/15  ...  Not fleeing       False  below25
# 3   8     Matthew Hoffman  04/01/15  ...  Not fleeing       False  above25
# 4   9   Michael Rodriguez  04/01/15  ...  Not fleeing       False  above25
#
# [5 rows x 15 columns]

# %%
age_cat = df["age_cat"].value_counts()
age_cat
# Out:
# above25    1905
# below25     630
# Name: age_cat, dtype: int64

# %%
type(age_cat)
# Out:
# function

# %%
# Out:
# above25    1905
# below25     630
# Name: age_cat, dtype: int64

# %%
# with pandas _my
age_cat.plot.bar(figsize=(6,4))

for index, value in enumerate(age_cat.values):
    plt.text(index, value, str(value), ha = "center")
plt.xticks(rotation=90)

plt.show()

# %%
# with pandas

# %%
# with matplotlib _ my
fig, ax = plt.subplots(figsize=(6,4))
plt.bar(age_cat.index, age_cat.values);
for index, value in enumerate(age_cat.values):
    plt.text(index, value, str(value), ha = "center")
plt.xticks()

plt.show()

# %%
# with matplotlib

# %% [markdown]
# ## 4: Plot number of killed poeple by race

# %%
df["race"].value_counts()
# Out:
# W    1201
# B     618
# H     423
# A      39
# N      31
# O      28
# Name: race, dtype: int64

# %%
# Out:
# W    1201
# B     618
# H     423
# A      39
# N      31
# O      28
# Name: race, dtype: int64

# %%
rfkp = df["race"].value_counts()

# %%
# with pandas_my
rfkp.plot.bar(figsize=(6,4), title = "Race of killed people")
plt.title("Race of killed people",color="Blue",fontsize=15)


plt.show()

# %%
# with pandas

# %%
# with matplotlib_my

fig, ax = plt.subplots(figsize=(6,4))
plt.bar(rfkp.index, rfkp.values);
plt.title("Race of killed people",color="Blue",fontsize=15)

plt.show()

# %%
# with matplotlib

# %% [markdown]
# ## 5: Killed People According to Races (Pie Chart)

# %%
# Out:
#    id                name      date  ...         flee body_camera  age_cat
# 0   3          Tim Elliot  02/01/15  ...  Not fleeing       False  above25
# 1   4    Lewis Lee Lembke  02/01/15  ...  Not fleeing       False  above25
# 2   5  John Paul Quintero  03/01/15  ...  Not fleeing       False  below25
# 3   8     Matthew Hoffman  04/01/15  ...  Not fleeing       False  above25
# 4   9   Michael Rodriguez  04/01/15  ...  Not fleeing       False  above25
#
# [5 rows x 15 columns]

# %%
df["race"].unique()
# Out:
# array(['A', 'W', 'H', 'B', 'O', nan, 'N'], dtype=object)

# %%
df["race"].isnull().sum()
# Out:
# 195

# %%
# Out:
# array(['A', 'W', 'H', 'B', 'O', nan, 'N'], dtype=object)

# %%
df['race'].value_counts(dropna=False)
# Out:
# W      1201
# B       618
# H       423
# NaN     195
# A        39
# N        31
# O        28
# Name: race, dtype: int64

# %%
# Out:
# W      1201
# B       618
# H       423
# NaN     195
# A        39
# N        31
# O        28
# Name: race, dtype: int64

# %% [markdown]
# Problem: missing value on race column.

# %% [markdown]
# **INSTRUCTION-1: Drop the all raws that contain missing value (dropna)**

# %%
df1 = df.dropna()

# %%
df1.shape
# Out:
# (2254, 15)

# %%
# Out:
# (2254, 15)

# %% [markdown]
# **INSTRUCTION-2: Demonstrate Race Ratio of Killed People by a Pie Chart (You can use Matplotlib)**

# %%
df1["race"].value_counts()
# Out:
# W    1168
# B     592
# H     401
# A      36
# N      29
# O      28
# Name: race, dtype: int64

# %%
# Out:
# W    1168
# B     592
# H     401
# A      36
# N      29
# O      28
# Name: race, dtype: int64

# %%
index = df1["race"].value_counts().index

# %%
index
# Out:
# Index(['W', 'B', 'H', 'A', 'N', 'O'], dtype='object')

# %%
# Out:
# Index(['W', 'B', 'H', 'A', 'N', 'O'], dtype='object')

# %%
# values = np.array(race_of_killed_the_people.values)
values = df1["race"].value_counts().values

# %%
values
# Out:
# array([1168,  592,  401,   36,   29,   28], dtype=int64)

# %%
# Out:
# array([1168,  592,  401,   36,   29,   28])

# %%
# matplotlib_my
plt.figure(figsize=(12,9))
y = values
mylabels = index
myexplode = [0, 0, 0.3, 0, 0, 0]

plt.pie(y, labels = mylabels, labeldistance=1.1, explode = myexplode, startangle=70, autopct='%1.1f%%')

plt.show(
# Out:
#   File "<ipython-input-25-82680b5ef4c2>", line 9
#     plt.show(
#              ^
# SyntaxError: unexpected EOF while parsing

# %%
# matplotlib

# %% [markdown]
# ## 6: Most common 15 Name or Surname of killed people

# %%
df1.head()
# Out:
#    id                name      date   manner_of_death       armed   age  \
# 0   3          Tim Elliot  02/01/15              shot         gun  53.0
# 1   4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2   5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4   9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera  age_cat
# 0  Not fleeing        False  above25
# 1  Not fleeing        False  above25
# 2  Not fleeing        False  below25
# 3  Not fleeing        False  above25
# 4  Not fleeing        False  above25

# %%
# Out:
#    id                name      date  ...         flee body_camera  age_cat
# 0   3          Tim Elliot  02/01/15  ...  Not fleeing       False  above25
# 1   4    Lewis Lee Lembke  02/01/15  ...  Not fleeing       False  above25
# 2   5  John Paul Quintero  03/01/15  ...  Not fleeing       False  below25
# 3   8     Matthew Hoffman  04/01/15  ...  Not fleeing       False  above25
# 4   9   Michael Rodriguez  04/01/15  ...  Not fleeing       False  above25
#
# [5 rows x 15 columns]

# %%
df1.shape
# Out:
# (2254, 15)

# %%
# Out:
# (2254, 15)

# %%
df1["name"].value_counts()
# Out:
# Michael Brown               2
# Eric Harris                 2
# Brandon Jones               2
# Michael Johnson             2
# Daquan Antonio Westbrook    2
#                            ..
# Angel Daniel Navarro        1
# Timothy Gene Smith          1
# Dave Phoenix                1
# Justin Prescott             1
# Joshua Grubb                1
# Name: name, Length: 2249, dtype: int64

# %%
# Out:
# Daquan Antonio Westbrook    2
# Michael Johnson             2
# Eric Harris                 2
# Michael Brown               2
# Brandon Jones               2
#                            ..
# Wayne Donald Dorsey         1
# Matthew Vincent Wood        1
# Taylor Hodge                1
# David L. Anderson           1
# Jovany Martinez             1
# Name: name, Length: 2249, dtype: int64

# %%
# Problem: TK TK is most probably not a name or surname. We will clean them.
# Out:
# 0             [Tim, Elliot]
# 1      [Lewis, Lee, Lembke]
# 2    [John, Paul, Quintero]
# 3        [Matthew, Hoffman]
# 4      [Michael, Rodriguez]
# Name: name, dtype: object

# %%
df1[df1['name'] == 'TK TK'].index
# Out:
# Int64Index([2465], dtype='int64')

# %%
df2 = df1.drop([2465])

# %%
df2.shape
# Out:
# (2253, 15)

# %%
pairs = df2['name'].str.split()
pairs
# Out:
# 0                [Tim, Elliot]
# 1         [Lewis, Lee, Lembke]
# 2       [John, Paul, Quintero]
# 3           [Matthew, Hoffman]
# 4         [Michael, Rodriguez]
#                  ...
# 2519            [Aries, Clark]
# 2523     [Kesharn, K., Burney]
# 2525       [Deltra, Henderson]
# 2533          [Isaiah, Tucker]
# 2534           [Dwayne, Jeune]
# Name: name, Length: 2253, dtype: object

# %%
type(pairs)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **INSTRUCTION : Plot Most common 15 Name OR Surname of killed people**

# %% [raw]
# ### Clue 1: You need to separate the names and surnames because we are asking most common name OR surname.
#
# ### Clue 2 :After seperation make a whole list that contains both names and surnames.
#
# ### Clue 3 : How to separate the name and surname pairs?
#
# >>> pairs = [(1, 'a'), (2, 'b'), (3, 'c'), (4, 'd')]
# >>> numbers, letters = zip(*pairs)
# >>> numbers
# (1, 2, 3, 4)
# >>> letters
# ('a', 'b', 'c', 'd')
#
# ### Clue 4: You can use Counter() and most_common() built in functions together to find the most common names or surnames, or you can write your own functions for this purpose.

# %% [markdown]
# shape

# %%
pairs.shape
# Out:
# (2253,)

# %%
# Out:
# (2253,)

# %%
pairs[0]
# Out:
# ['Tim', 'Elliot']

# %%
# Out:
# ['Tim', 'Elliot']

# %%
pairs.iloc[0][0]
# Out:
# 'Tim'

# %%
# Out:
# 'Tim'

# %%
# Out:
# 5339

# %%
names, surnames = zip(*pairs)

# %%
name_surname = names + surnames
name_surname_counts = Counter(name_surname)

# %%
name_surname_counts
# Out:
# 'Betty': 1,
#          'Douglas': 9,
#          'Pedro': 4,
#          'Janisha': 1,
#          'Ruben': 6,
#          'Stanley': 3,
#          'Kent': 1,
#          'Bradford': 1,
#          'Jerome': 5,
#          "A'Donte": 1,
#          'Glenn': 4,
#          'Alexander': 13,
#          'Amilcar': 1,
#          'Rodney': 9,
#          'Crystal': 1,
#          'Ernesto': 3,
#          'Chazsten': 1,
#          'Deven': 1,
#          'Jessica': 2,
#          'Cornelius': 2,
#          'Ian': 2,
#          'Stephanie': 1,
#          'Donald': 9,
#          'Charly': 1,
#          'Hung': 1,
#          'Shaquille': 1,
#          'Fednel': 1,
#          'Derek': 9,
#          'Carl': 4,
#          'Tyrone': 5,
#          'Sergio': 6,
#          'Tyson': 1,
#          'Naeschylus': 1,
#          'Tony': 2,
#          'Adam': 6,
#          'Aurelio': 1,
#          'Monique': 1,
#          'Lester': 1,
#          'Cedrick': 1,
#          'Jamie': 5,
#          'Christopher': 35,
#          'Edixon': 1,
#          'Theodore': 1,
#          'Benito': 1,
#          'Ryan': 15,
#          'Aaron': 8,
#          'Gilbert': 4,
#          'William': 40,
#          'Terry': 6,
#          'Bobby': 7,
#          'Fred': 4,
#          'Clifton': 2,
#          'Troy': 2,
#          'Justin': 9,
#          'Eugene': 11,
#          'Roberto': 3,
#          'Declan': 1,
#          'Alice': 1,
#          'Jeff': 5,
#          'Kaylene': 1,
#          'Garland': 2,
#          'Kendre': 1,
#          'Jamison': 2,
#          'Shane': 7,
#          'Brandon': 19,
#          'Tyrel': 1,
#          'Gary': 10,
#          'Enoch': 1,
#          'Denzel': 1,
#          'Devin': 5,
#          'Stephen': 10,
#          'Walter': 4,
#          'Deanne': 1,
#          'Adrian': 4,
#          'Jamalis': 1,
#          'Neil': 3,
#          'Megan': 1,
#          'Harvey': 1,
#          'Angelo': 3,
#          'Byron': 1,
#          'Benjamin': 5,
#          'Mya': 1,
#          'Shawn': 6,
#          'Darrin': 3,
#          'Eric': 16,
#          'Justus': 1,
#          'Ethan': 3,
#          'Ken': 1,
#          'Tyrell': 1,
#          'Erick': 2,
#          'Dexter': 2,
#          'Gordon': 1,
#          'Don': 5,
#          'Jess': 1,
#          'Angel': 14,
#          'Mack': 2,
#          'Colby': 2,
#          'Tevin': 1,
#          'Dante': 2,
#          'Frank': 4,
#          'Mark': 20,
#          'Rodolfo': 1,
#          'Elias': 2,
#          'Thaddeus': 2,
#          'Erik': 3,
#          'Grover': 1,
#          'Dana': 3,
#          'Santos': 2,
#          'Kimber': 1,
#          'Luis': 7,
#          'Carlos': 12,
#          'Reginald': 3,
#          'Lue': 1,
#          'Hector': 5,
#          'Karen': 1,
#          'Billy': 5,
#          'Albert': 5,
#          'Dean': 7,
#          'Terrance': 1,
#          'Jared': 1,
#          'Alexia': 1,
#          'Fridoon': 1,
#          'Kevin': 16,
#          'Elton': 1,
#          'Nadir': 1,
#          'Roark': 1,
#          'Brendon': 1,
#          'Thong': 1,
#          'Nephi': 2,
#          'Shaun': 2,
#          'Dedrick': 1,
#          'Sam': 2,
#          'Lionel': 4,
#          'Kelvin': 1,
#          "D'Angelo": 1,
#          'Alec': 1,
#          'Sean': 6,
#          'Cary': 1,
#          'Matt': 2,
#          'Ronell': 1,
#          'Dennis': 8,
#          'Austin': 6,
#          'Timothy': 12,
#          'Alfredo': 1,
#          'Chrislon': 1,
#          'Nikki': 1,
#          'Javoris': 1,
#          'Elvin': 1,
#          'Caso': 1,
#          'Cassandra': 1,
#          'Millard': 2,
#          'Dalton': 2,
#          'Garrett': 1,
#          'Harry': 1,
#          'Feras': 1,
#          'Simon': 2,
#          'Darrell': 3,
#          'Kyle': 8,
#          'Nehemiah': 1,
#          'Ebin': 1,
#          'Usaamah': 1,
#          'Kamal': 1,
#          'Lorenzo': 4,
#          'Rudy': 1,
#          'Edelmiro': 1,
#          'Ronald': 7,
#          'Jesus': 6,
#          'Christie': 1,
#          'Demouria': 1,
#          'Alejandro': 5,
#          'Joe': 9,
#          'Damien': 2,
#          'Gene': 5,
#          'Rene': 4,
#          'Greg': 2,
#          'QuanDavier': 1,
#          'Isiah': 1,
#          'Charles': 23,
#          'Fritz': 1,
#          'Shelly': 2,
#          'Deng': 1,
#          'Zane': 1,
#          'Kris': 2,
#          'Wendy': 1,
#          'Oleg': 1,
#          'Trepierre': 1,
#          'Louis': 3,
#          'Alfontish': 1,
#          'Eduardo': 3,
#          'Tyler': 10,
#          'Randall': 4,
#          'Taylor': 5,
#          'Spencer': 3,
#          'Clay': 2,
#          'Kaleb': 2,
#          'Ton': 1,
#          'Cesar': 4,
#          'Arturo': 3,
#          'Oscar': 4,
#          'Kawanza': 1,
#          'Bryan': 5,
#          'Johnny': 3,
#          'Hagen': 1,
#          'Marcellus': 1,
#          'Tremaine': 1,
#          'Dallas': 1,
#          'Rocco': 1,
#          'Martice': 1,
#          'Cyrus': 1,
#          'Javon': 1,
#          'Freddie': 1,
#          'Salvado': 1,
#          'Frederick': 4,
#          'Rafael': 3,
#          'Chacarion': 1,
#          'Anthonie': 1,
#          'Mohammad': 4,
#          'Saige': 1,
#          'Pierre': 2,
#          'Samuel': 5,
#          'Jackie': 2,
#          'Darrius': 1,
#          'Darren': 4,
#          'Jerrod': 2,
#          'Francisco': 6,
#          'Andre': 3,
#          'Devon': 2,
#          'Dontae': 1,
#          'Robbie': 1,
#          'Tamala': 1,
#          'Seth': 1,
#          'Lee': 36,
#          'Roger': 5,
#          'Earl': 9,
#          'Khari': 1,
#          'Zachary': 2,
#          'Jean': 3,
#          'Philip': 5,
#          'Armando': 4,
#          'Virgil': 1,
#          'Franklin': 1,
#          'Darius': 4,
#          'Keshawn': 1,
#          'Vincente': 1,
#          'Gustavo': 2,
#          'Christian': 8,
#          'Abel': 1,
#          'Tsombe': 1,
#          'Derrick': 2,
#          'Shamir': 1,
#          'Edrian': 1,
#          'Casey': 3,
#          'Nathaniel': 4,
#          'Redel': 1,
#          'Asshams': 1,
#          'Allen': 19,
#          'Jonathon': 1,
#          'Steven': 13,
#          'Mansur': 1,
#          'Deviere': 1,
#          'Wade': 3,
#          'Jeffory': 1,
#          'Raul': 3,
#          'Timmy': 1,
#          'Julian': 3,
#          'Marvin': 4,
#          'Curtis': 4,
#          'Brent': 6,
#          'Bertrand': 1,
#          'Yonas': 1,
#          'Manuel': 6,
#          'Felix': 2,
#          'Cedric': 4,
#          'Arthur': 5,
#          'Freddy': 2,
#          'Sully': 1,
#          'Harrison': 2,
#          "La'vante": 1,
#          'India': 2,
#          'Mohamed': 2,
#          'Casimero': 1,
#          'Tristan': 3,
#          'Dustin': 2,
#          'Tian': 1,
#          'Eddie': 4,
#          'Derick': 1,
#          'Jack': 4,
#          'Martin': 9,
#          'Clifford': 3,
#          'Florencio': 2,
#          'Jorge': 8,
#          'Rory': 1,
#          'Gregory': 4,
#          'Lucien': 1,
#          'Jerrald': 1,
#          'Gerardo': 4,
#          'Tina': 2,
#          'Dominic': 4,
#          'Joel': 7,
#          'Keith': 14,
#          'Norma': 1,
#          'Junior': 2,
#          'Alberto': 2,
#          'Phyllis': 1,
#          'Jeffery': 2,
#          'Omar': 6,
#          'Amado': 1,
#          'Travis': 9,
#          'Bernard': 3,
#          'Rudolph': 2,
#          'Michelle': 4,
#          'Linda': 1,
#          'Ricky': 3,
#          'Gino': 2,
#          'Dequan': 1,
#          'Corey': 4,
#          'Krikor': 1,
#          'Dion': 2,
#          'Lamontez': 1,
#          'Darien': 1,
#          'Adriene': 1,
#          'Juan': 12,
#          'Rolly': 1,
#          'Jon': 2,
#          'Marquesha': 1,
#          'Kobvey': 1,
#          'Tyrie': 1,
#          'Jerry': 3,
#          'Jasper': 1,
#          'Floyd': 1,
#          'Noah': 1,
#          'Bennie': 1,
#          'Luverne': 1,
#          'Killian': 1,
#          'Faisal': 1,
#          'Laura': 1,
#          'Kim': 2,
#          'Delvin': 1,
#          'Dale': 4,
#          'Leonel': 1,
#          'Javier': 4,
#          'Moises': 1,
#          'Ramon': 5,
#          'Jamar': 1,
#          'Cameron': 5,
#          'Yohans': 1,
#          'Demetrius': 4,
#          'Jeray': 1,
#          'Derry': 1,
#          'Steve': 2,
#          'Darick': 1,
#          'Henry': 9,
#          'Barry': 6,
#          'Magnum': 1,
#          'Somer': 1,
#          'Rick': 1,
#          'Hugo': 1,
#          'Tuan': 1,
#          'Fernando': 6,
#          'Tashfeen': 1,
#          'Syed': 1,
#          'Ivan': 2,
#          'Raymone': 1,
#          'Colten': 1,
#          'Sheilah': 1,
#          'Carlumandarlo': 1,
#          'Javario': 1,
#          'Shirley': 1,
#          'Enrique': 1,
#          'Calvin': 2,
#          'Brenda': 1,
#          'Mharloun': 1,
#          'Ronnie': 4,
#          'Erica': 1,
#          'Amos': 1,
#          'Leroy': 5,
#          'Guadalupe': 2,
#          'Chan': 1,
#          'Schuylar': 1,
#          'Terrozza': 1,
#          'Daquan': 3,
#          'Lonnie': 3,
#          'Quintonio': 1,
#          'Gayneaux': 1,
#          'Siolosega': 1,
#          'Lance': 5,
#          'Germonta': 1,
#          'Carlton': 1,
#          'Christine': 1,
#          'Ramone': 1,
#          'Ciara': 1,
#          'Herman': 2,
#          'Willie': 3,
#          'Rakeem': 1,
#          'Alfred': 4,
#          'Ashton': 1,
#          'Kelsey': 1,
#          'Clarence': 2,
#          'Crayton': 1,
#          'Efrain': 2,
#          'Jordan': 5,
#          'Levi': 2,
#          'Vasilios': 1,
#          'Jim': 1,
#          'Randy': 6,
#          'Johnathan': 2,
#          'Thongsavanh': 1,
#          'Janet': 1,
#          'Israel': 2,
#          'Jacqueline': 2,
#          'Randolph': 2,
#          'Angela': 1,
#          'Peter': 9,
#          'Edgar': 4,
#          'Cristiaan': 1,
#          'Kayden': 1,
#          'Antronie': 1,
#          'Blake': 5,
#          'Vinson': 2,
#          'Marese': 1,
#          'Shalamar': 1,
#          'Scottie': 1,
#          'Alijah': 1,
#          'Sahlah': 1,
#          'Ali': 2,
#          'Calin': 1,
#          'Dyzhawn': 1,
#          'Rammy': 1,
#          'Marc': 2,
#          'Destry': 1,
#          'Danny': 2,
#          'Marcos': 2,
#          'Che': 1,
#          'Sherrisa': 1,
#          'Kisha': 2,
#          'Marquintan': 1,
#          'Patricia': 1,
#          'Gerardino': 1,
#          'Rouven': 1,
#          'Baltazar': 1,
#          'Alex': 2,
#          'Luke': 3,
#          'Kionte': 1,
#          'Abraham': 4,
#          'Akiel': 1,
#          'Dimitri': 1,
#          'Mickey': 1,
#          'Osvaldo': 1,
#          'Bryon': 1,
#          'Wesley': 5,
#          'Arteair': 1,
#          'German': 1,
#          'Tyre': 3,
#          'Manford': 1,
#          'Teodoro': 1,
#          'Marco': 2,
#          'Gevork': 1,
#          'Amy': 1,
#          'Jacai': 1,
#          'Lamar': 4,
#          'Ed': 2,
#          'Cristian': 1,
#          'Map': 1,
#          'Sunny': 1,
#          'Thurman': 1,
#          'Dylan': 6,
#          'Boyd': 2,
#          'Daven': 1,
#          'Alexio': 1,
#          'Dominique': 2,
#          'Jermon': 1,
#          'Terrence': 4,
#          'Loreal': 1,
#          'Deriante': 1,
#          'Denise': 1,
#          'Kimani': 1,
#          'Melissa': 3,
#          'Laronda': 1,
#          'Dazion': 1,
#          'Lamont': 7,
#          'Diahlo': 1,
#          'Quron': 1,
#          'Efren': 1,
#          'Koltlee': 1,
#          'Clemente': 1,
#          'Storm': 1,
#          'Gerald': 2,
#          'George': 9,
#          'Edson': 1,
#          'Rico': 1,
#          'Sylasone': 1,
#          'Jorevis': 1,
#          'Demarcus': 1,
#          'Mitchell': 3,
#          'Jakob': 1,
#          'Kay': 1,
#          'Robin': 3,
#          'Jacquelyn': 1,
#          'Darrel': 2,
#          'Cin': 1,
#          'Damon': 5,
#          'Kendar': 1,
#          'Ashtian': 1,
#          'Oswald': 1,
#          'Bender': 1,
#          'Marion': 2,
#          'Charlin': 1,
#          'Cayce': 1,
#          'Gerry': 1,
#          'Burt': 1,
#          'Deresha': 1,
#          'Alton': 3,
#          'Jaffort': 1,
#          'Thongsoune': 1,
#          'Dracy': 1,
#          'Jabril': 1,
#          'Garry': 1,
#          'Jeremias': 1,
#          'Jaime': 1,
#          'Kentrill': 1,
#          'Norman': 4,
#          'Vernell': 1,
#          'Bryson': 1,
#          'Verl': 1,
#          'Bodhi': 1,
#          'Doll': 1,
#          'Warren': 1,
#          'Devonte': 1,
#          'Dionisio': 1,
#          'Osee': 1,
#          'Hubert': 1,
#          'Demarco': 2,
#          'Kalyp': 1,
#          'Willis': 3,
#          'Clayton': 1,
#          'J.': 30,
#          'Lyndarius': 1,
#          'Noel': 4,
#          'Russell': 4,
#          'Sergey': 1,
#          'Antwun': 1,
#          'Rashaun': 1,
#          'Raufeal': 1,
#          'Lane': 3,
#          'Josiah': 1,
#          'Isaiah': 5,
#          'Quencezola': 1,
#          'Deravis': 1,
#          'Jay': 5,
#          'Ismael': 2,
#          'Christy': 1,
#          'Jamil': 1,
#          'Waldemar': 1,
#          'Rodrigo': 1,
#          'Germichael': 1,
#          'Sherman': 1,
#          'Walden': 1,
#          'Lafayette': 1,
#          'Jasen': 1,
#          'Alexis': 1,
#          'Helmut': 1,
#          'Jai': 1,
#          'Shannon': 3,
#          'Sidney': 1,
#          'Philando': 1,
#          'Earnest': 1,
#          'Alva': 1,
#          'Orville': 1,
#          'Dayten': 1,
#          'Jermaine': 2,
#          'Gavin': 3,
#          'BJ': 1,
#          'Alvin': 1,
#          'Scot': 2,
#          'Dalvin': 1,
#          'Saddam': 1,
#          'Emil': 1,
#          'Donnell': 2,
#          'Melvin': 2,
#          'Amanda': 1,
#          'Limichael': 1,
#          'Korryn': 1,
#          'DeMarco': 1,
#          'Bradley': 4,
#          'E.J.': 1,
#          'Johannes': 2,
#          'Jamarion': 1,
#          'Jawari': 1,
#          'Darnell': 6,
#          'Jesse': 6,
#          'Sylville': 1,
#          'Perry': 2,
#          'Jovany': 1,
#          'Kenney': 1,
#          'Omer': 1,
#          'Chad': 5,
#          'Trenton': 1,
#          'Marcelo': 1,
#          'Kole': 1,
#          'Kelley': 2,
#          'Donta': 1,
#          'Jaqwan': 1,
#          'Paula': 1,
#          'Levonia': 1,
#          'Lyle': 1,
#          'Caleb': 2,
#          'Donny': 1,
#          'Moses': 1,
#          'Sadiq': 1,
#          'Ricardo': 3,
#          'Morgan': 4,
#          'Lucas': 2,
#          'Dahir': 1,
#          'Sandy': 1,
#          'Oddis': 1,
#          'Leeland': 1,
#          'Najier': 1,
#          'Jacquarius': 1,
#          'Carnell': 1,
#          'Isaias': 1,
#          'Deric': 1,
#          'Maurico': 1,
#          'Devan': 1,
#          'Dominick': 1,
#          'Blaine': 2,
#          'Kirk': 2,
#          'Chaz': 1,
#          'Micah': 2,
#          'Rolando': 1,
#          'Keegan': 1,
#          'Deborah': 1,
#          'Renee': 1,
#          'Kristofer': 1,
#          'Kenny': 1,
#          'Chelsea': 1,
#          'Malcolm': 1,
#          'Thad': 1,
#          'Edwin': 2,
#          'Jun': 1,
#          'Ashley': 1,
#          'Wilton': 1,
#          'Ferguson': 2,
#          'Darryl': 2,
#          'Kenton': 1,
#          'Evan': 1,
#          'Rasheem': 1,
#          'Edmund': 1,
#          'Samson': 2,
#          'Dontrell': 2,
#          'Adalid': 1,
#          'Erickson': 2,
#          'Ivory': 1,
#          'Talif': 1,
#          'Kajuan': 1,
#          'Terrell': 2,
#          'Abdul': 1,
#          'Irecas': 1,
#          'Toby': 1,
#          'Quinton': 1,
#          'Josh': 1,
#          'Saif': 1,
#          'Westley': 1,
#          'Wayne': 10,
#          'Redrick': 1,
#          'Waltki': 1,
#          'Amber': 1,
#          'Rainer': 1,
#          'Lavar': 1,
#          'Fidel': 1,
#          'Chassady': 1,
#          'Colton': 2,
#          'Miriam': 1,
#          'Zhonghua': 1,
#          'Judy': 1,
#          'Alfonso': 1,
#          'Jake': 2,
#          'Jamal': 5,
#          'Chase': 1,
#          'Trevon': 2,
#          'Welby': 1,
#          'JR': 1,
#          'Davion': 1,
#          'Darrion': 1,
#          'Hafez': 1,
#          'Jahlire': 1,
#          'Sinuon': 1,
#          'Marlon': 1,
#          'Stoney': 1,
#          'Genevive': 1,
#          'Marquis': 2,
#          'Elijah': 1,
#          'Armond': 1,
#          'Josue': 2,
#          'Dakota': 1,
#          'Arties': 1,
#          'Donovan': 1,
#          'Kerry': 1,
#          'Deaundre': 1,
#          "Mi'Chance": 1,
#          'Refugio': 1,
#          'Tavis': 1,
#          'Yia': 1,
#          'Jamake': 1,
#          'Johnnie': 1,
#          'Nana': 1,
#          'Cole': 1,
#          'Quanice': 1,
#          'Jocques': 1,
#          'Pekelo': 1,
#          'Alonzo': 1,
#          'Willard': 1,
#          'Drey': 1,
#          'Raynard': 1,
#          'Mauro': 1,
#          'Kadeem': 1,
#          'Chance': 3,
#          'Keo': 1,
#          'Bartolo': 1,
#          'Misael': 1,
#          'Medger': 1,
#          'Jimmie': 3,
#          'Joey': 2,
#          'Evin': 1,
#          'Epthen': 1,
#          'Isidro': 1,
#          'Dave': 1,
#          'Iaroslav': 1,
#          'Rashad': 2,
#          'Cordale': 1,
#          'Brentant': 1,
#          'Nancy': 1,
#          'Alteria': 1,
#          'Trevor': 2,
#          'Reno': 1,
#          'Pryor': 1,
#          'Doyle': 1,
#          'Rogelio': 1,
#          'Zelalem': 1,
#          'Sariah': 1,
#          'Kendell': 1,
#          'Jacy': 1,
#          'Selwyn': 1,
#          'Burgon': 1,
#          'Avery': 2,
#          'Mirza': 1,
#          'Malik': 2,
#          'Landon': 2,
#          'Mikel': 1,
#          'Jayson': 1,
#          'Jeroen': 1,
#          'Maxwell': 1,
#          'Jonie': 1,
#          'Jaison': 1,
#          'Buford': 1,
#          'Isabelle': 1,
#          'Marshall': 5,
#          'Ricco': 1,
#          'Hayden': 1,
#          'Shaquian': 1,
#          'Roman': 2,
#          'Naway': 1,
#          'Corsean': 1,
#          'Quentin': 1,
#          'Emmett': 1,
#          'Eleuterio': 1,
#          'Chazz': 1,
#          'Charleena': 1,
#          'Robb': 1,
#          'Giovonn': 1,
#          'Deveonte': 1,
#          'Brett': 1,
#          'Quintec': 1,
#          'Justine': 1,
#          'Aries': 1,
#          'Kesharn': 1,
#          'Deltra': 1,
#          'Dwayne': 2,
#          'Elliot': 1,
#          'Hoffman': 2,
#          'Rodriguez': 7,
#          'Arnold': 2,
#          'Nichols': 3,
#          'Steele': 1,
#          'Sapp': 2,
#          'Wetter': 1,
#          'Sneed': 1,
#          'Hanif': 1,
#          'Simpson': 3,
#          'Dudley': 1,
#          'Hamby': 1,
#          'Foreman': 1,
#          'Martinez': 7,
#          'Smith': 19,
#          'Barbosa': 1,
#          'Figueroa': 2,
#          'McClendon': 2,
#          'Golden': 1,
#          'Goebel': 1,
#          'Schroeder': 1,
#          'Edwards': 4,
#          'R.': 10,
#          'Sowell': 2,
#          'Reed': 2,
#          'Ceja': 1,
#          'Massey': 1,
#          'Hall': 7,
#          'Shinwary': 1,
#          'Walker': 2,
#          'Meza': 1,
#          'Brumley': 1,
#          'Guillory': 1,
#          'Castle': 1,
#          'Campbell': 2,
#          'Carr': 2,
#          'Holmes': 2,
#          'Toto': 1,
#          'Meton': 1,
#          'Coignard': 1,
#          'Turner': 2,
#          'King': 4,
#          'Myler': 1,
#          'Hutchins': 1,
#          'Jude': 1,
#          'Hernandez': 11,
#          'Kmetz': 1,
#          'Garcia': 9,
#          'Leland': 2,
#          'Ingram': 1,
#          'Nuu': 1,
#          'Karasek': 1,
#          'Haglund': 1,
#          'Kassick': 1,
#          'Murphy': 2,
#          'D.': 14,
#          'Henderson': 4,
#          'Deshawn': 1,
#          'Purvis': 1,
#          'Lett': 1,
#          'Colon': 1,
#          'Muna': 1,
#          'Ray': 12,
#          'Atkins': 1,
#          'Hill': 3,
#          'Flache': 1,
#          'Cordaro': 1,
#          'Paffen': 1,
#          'Hostetter': 1,
#          'Kreyssig': 1,
#          'Luster': 1,
#          'Zambrano-Montes': 1,
#          'Bess': 1,
#          'Fritze': 1,
#          'Watkins': 3,
#          'Lara-Rodriguez': 1,
#          'Carlin': 1,
#          'Mejia': 2,
#          'C.': 8,
#          'Joy': 1,
#          'Steward': 1,
#          'Caldwell': 2,
#          'K.': 4,
#          'Evans': 4,
#          'Sexton': 1,
#          'Ireland': 1,
#          'Lundy': 1,
#          'Sparks': 1,
#          'Fonville': 1,
#          'Villalpando': 1,
#          'Harris': 8,
#          'Moncrief': 1,
#          'Leonard': 2,
#          'Elrod': 1,
#          'Kohl': 1,
#          'Giaquinta': 1,
#          'Washington': 5,
#          'Biegert': 1,
#          'Spivey': 1,
#          'Cuevas': 1,
#          'Perez-Lopez': 1,
#          'Biggs': 1,
#          'Javiar': 1,
#          'Freeman': 1,
#          'Guilford': 1,
#          'Uribe': 1,
#          'Sherrod': 1,
#          'Leundeu': 1,
#          'Trieu': 1,
#          'Barrow': 1,
#          'Rhinvil': 1,
#          'Metz': 1,
#          'Cruice': 1,
#          'Lao': 1,
#          'Ryerson': 1,
#          'Hubbard': 1,
#          'Vinzant': 1,
#          'Robinson': 4,
#          'Reinhart': 1,
#          'Duarte': 1,
#          'McKillop': 1,
#          'Jenee': 1,
#          'Brown': 10,
#          'Croom': 1,
#          'Franco': 1,
#          'Johnson': 17,
#          'Greenwell': 1,
#          'Osorio': 1,
#          'Valdez': 2,
#          ...})

# %%
# Out:
# Counter({'Tim': 3,
#          'Elliot': 1,
#          'Lewis': 7,
#          'Lee': 37,
#          'Lembke': 1,
#          'John': 36,
#          'Paul': 16,
#          'Quintero': 2,
#          'Matthew': 22,
#          'Hoffman': 2,
#          'Michael': 82,
#          'Rodriguez': 13,
#          'Kenneth': 17,
#          'Joe': 9,
#          'Brown': 17,
#          'Arnold': 2,
#          'Buck': 3,
#          'Brock': 2,
#          'Nichols': 3,
#          'Autumn': 1,
#          'Steele': 1,
#          'Leslie': 2,
#          'Sapp': 2,
#          'III': 9,
#          'Patrick': 13,
#          'Wetter': 1,
#          'Ron': 2,
#          'Sneed': 1,
#          'Hashim': 1,
#          'Hanif': 1,
#          'Ibn': 1,
#          'Abdul-Rasheed': 1,
#          'Nicholas': 13,
#          'Ryan': 16,
#          'Brickman': 1,
#          'Omarr': 1,
#          'Julian': 3,
#          'Maximillian': 1,
#          'Jackson': 9,
#          'Loren': 3,
#          'Simpson': 4,
#          'James': 47,
#          'Dudley': 1,
#          'Barker': 2,
#          'Artago': 1,
#          'Damon': 6,
#          'Howard': 3,
#          'Thomas': 24,
#          'Hamby': 1,
#          'Jimmy': 5,
#          'Foreman': 1,
#          'Andy': 1,
#          'Martinez': 10,
#          'Tommy': 3,
#          'Smith': 31,
#          'Brian': 9,
#          'Barbosa': 1,
#          'Salvador': 4,
#          'Figueroa': 2,
#          'Edward': 15,
#          "O'Keefe": 1,
#          'Richard': 33,
#          'McClendon': 2,
#          'Marcus': 4,
#          'Golden': 1,
#          'Goebel': 1,
#          'Mario': 8,
#          'Jordan': 5,
#          'Talbot': 1,
#          'Schroeder': 2,
#          'Robert': 44,
#          'Edwards': 6,
#          'Jeffrey': 17,
#          'R.': 10,
#          'Nielson': 1,
#          'Donte': 3,
#          'Sowell': 2,
#          'Kavonda': 1,
#          'Earl': 9,
#          'Payton': 1,
#          'Quincy': 2,
#          'Reed': 2,
#          'Reindl': 1,
#          'Jose': 23,
#          'Ceja': 1,
#          'Nathan': 6,
#          'Massey': 1,
#          'Scott': 25,
#          'Hall': 13,
#          'Zaki': 1,
#          'Shinwary': 1,
#          'Terence': 3,
#          'Walker': 3,
#          'Pablo': 3,
#          'Meza': 1,
#          'Daniel': 40,
#          'Brumley': 1,
#          'Jonathan': 10,
#          'Guillory': 1,
#          'Carter': 5,
#          'Castle': 1,
#          'Campbell': 4,
#          'Dewayne': 3,
#          'Carr': 2,
#          'Todd': 10,
#          'Allen': 20,
#          'Hodge': 4,
#          'Miguel': 9,
#          'Angel': 14,
#          'de': 1,
#          'Santos-Rodriguez': 1,
#          'Isaac': 2,
#          'Holmes': 2,
#          'Andrew': 19,
#          'Toto': 1,
#          'Tiano': 1,
#          'Meton': 1,
#          'Kristiana': 1,
#          'Coignard': 1,
#          'Francis': 12,
#          'Mesch': 1,
#          'Demaris': 1,
#          'Turner': 3,
#          'Antonio': 14,
#          'Espinoza': 1,
#          'Ruiz': 2,
#          'Wendell': 1,
#          'King': 4,
#          'Daryl': 1,
#          'Myler': 1,
#          'Darin': 1,
#          'Hutchins': 1,
#          'Orlando': 1,
#          'Jude': 1,
#          'Lopez': 7,
#          'Jessie': 3,
#          'Hernandez': 13,
#          'Raymond': 10,
#          'Kmetz': 1,
#          'Joshua': 27,
#          'Omar': 6,
#          'Garcia': 12,
#          'David': 53,
#          'Nicolas': 2,
#          'Leland': 2,
#          'Tewa': 1,
#          'Chris': 3,
#          'Ingram': 1,
#          'Jermonte': 1,
#          'Fletcher': 4,
#          'Tiffany': 2,
#          'Terry': 7,
#          'Alan': 11,
#          'Lance': 5,
#          'Alverson': 1,
#          'Matautu': 1,
#          'Nuu': 1,
#          'Cody': 6,
#          'Karasek': 1,
#          'Ralph': 3,
#          'Willis': 3,
#          'Barry': 6,
#          'Marshall': 6,
#          'Victor': 6,
#          'Manuel': 6,
#          'Reyes': 6,
#          'Donnell': 2,
#          'Bright': 1,
#          'Jacob': 6,
#          'Haglund': 1,
#          'Kassick': 1,
#          'Murphy': 3,
#          'Rose': 3,
#          'Ledarius': 1,
#          'D.': 14,
#          'Williams': 16,
#          'Yuvette': 1,
#          'Henderson': 5,
#          'Deshawn': 1,
#          'Ward': 1,
#          'Anthony': 26,
#          'Purvis': 1,
#          'Jeremy': 12,
#          'Lett': 1,
#          'Izzy': 1,
#          'Colon': 1,
#          'Muna': 1,
#          'Joaquin': 1,
#          'Ray': 13,
#          'Robinson': 8,
#          'Jr.': 18,
#          'Markell': 2,
#          'Atkins': 1,
#          'Alfred': 4,
#          'Eugene': 12,
#          'Johnson': 29,
#          'Herbert': 5,
#          'Hill': 4,
#          'Sawyer': 2,
#          'Martin': 13,
#          'Whittaker': 1,
#          'Flache': 1,
#          'Vincent': 5,
#          'Cordaro': 1,
#          'Joseph': 43,
#          'Paffen': 1,
#          'Larry': 6,
#          'Hostetter': 1,
#          'Kreyssig': 1,
#          'Desmond': 3,
#          'Luster': 1,
#          'Zambrano-Montes': 1,
#          'Bess': 2,
#          'Fritze': 1,
#          'Phillip': 9,
#          'Watkins': 4,
#          'Stewart': 3,
#          'Harden': 1,
#          'Andres': 1,
#          'Lara-Rodriguez': 1,
#          'Carlin': 1,
#          'Belk': 1,
#          'Mejia': 2,
#          'Jason': 22,
#          'C.': 8,
#          'Hendrix': 2,
#          'Roy': 6,
#          'Joy': 1,
#          'Day': 2,
#          'Lavall': 1,
#          'Brent': 6,
#          'Means': 1,
#          'Bruce': 7,
#          'Steward': 1,
#          'Lawrence': 5,
#          'Caldwell': 2,
#          'K.': 4,
#          'Casper': 1,
#          'Evans': 8,
#          'Betty': 1,
#          'Sexton': 2,
#          'Ireland': 1,
#          'Lundy': 1,
#          'Douglas': 11,
#          'Sparks': 1,
#          'Pedro': 4,
#          'Juan': 12,
#          'Saldivar': 1,
#          'Janisha': 1,
#          'Fonville': 1,
#          'Ruben': 6,
#          'Villalpando': 1,
#          'Stanley': 4,
#          'Lamar': 4,
#          'Grant': 4,
#          'Harris': 11,
#          'Moncrief': 1,
#          'Kent': 2,
#          'Norman': 4,
#          'Bradford': 1,
#          'Leonard': 2,
#          'Jerome': 5,
#          'Elrod': 1,
#          'Kohl': 1,
#          'Wayne': 10,
#          'Smashey': 1,
#          'Giaquinta': 1,
#          "A'Donte": 1,
#          'Washington': 6,
#          'Biegert': 1,
#          'Glenn': 4,
#          'Spivey': 1,
#          'Alexander': 13,
#          'Long': 6,
#          'Cuevas': 1,
#          'Amilcar': 1,
#          'Perez-Lopez': 1,
#          'Rodney': 9,
#          'Biggs': 2,
#          'Crystal': 1,
#          'Miley': 1,
#          'Harry': 2,
#          'Ernesto': 3,
#          'Javiar': 1,
#          'Canepa': 1,
#          'Diaz': 5,
#          'Chazsten': 1,
#          'Freeman': 1,
#          'Deven': 1,
#          'Guilford': 1,
#          'Jessica': 2,
#          'Uribe': 1,
#          'Cornelius': 2,
#          'J.': 30,
#          'Parker': 4,
#          'Ian': 2,
#          'Sherrod': 1,
#          'Stephanie': 1,
#          'Donald': 9,
#          'Matkins': 1,
#          'Charly': 1,
#          'Leundeu': 1,
#          'Keunang': 1,
#          'Hung': 1,
#          'Trieu': 1,
#          'Shaquille': 1,
#          'Barrow': 1,
#          'Fednel': 1,
#          'Rhinvil': 1,
#          'Metz': 1,
#          'Derek': 9,
#          'Cruice': 1,
#          'Carl': 4,
#          'Lao': 1,
#          'Tyrone': 5,
#          'Ryerson': 1,
#          'Sergio': 6,
#          'Navas': 1,
#          'Tyson': 2,
#          'Hubbard': 1,
#          'Naeschylus': 1,
#          'Vinzant': 1,
#          'Tony': 2,
#          'Adam': 6,
#          'Reinhart': 1,
#          'Aurelio': 1,
#          'Duarte': 1,
#          'McKillop': 1,
#          'Monique': 1,
#          'Jenee': 1,
#          'Deckard': 1,
#          'Lester': 1,
#          'Cedrick': 1,
#          'Lamont': 7,
#          'Bishop': 1,
#          'Jamie': 5,
#          'Croom': 1,
#          'Christopher': 35,
#          'Mitchell': 3,
#          'Edixon': 1,
#          'Franco': 2,
#          'Theodore': 1,
#          'Greenwell': 1,
#          'Benito': 1,
#          'Osorio': 1,
#          'Dean': 8,
#          'Burgess': 4,
#          'Aaron': 8,
#          'Valdez': 3,
#          'Gilbert': 4,
#          'Fleury': 1,
#          'William': 40,
#          'Russell': 5,
#          'Garnett': 1,
#          'Bobby': 7,
#          'Gross': 1,
#          'Fred': 4,
#          'Liggett': 1,
#          'Driver': 1,
#          'Perez': 7,
#          'Jimenez': 2,
#          'Castilleja': 1,
#          'Clifton': 2,
#          'Reintzel': 1,
#          'Siler': 1,
#          'Troy': 2,
#          'Boyd': 3,
#          'Justin': 9,
#          'Tolkinen': 1,
#          'Poole': 1,
#          'Roberto': 3,
#          'Leon': 4,
#          'Charles': 23,
#          'Shipley': 1,
#          'Declan': 1,
#          'Owen': 1,
#          'Alice': 1,
#          'Jeff': 5,
#          'Kaylene': 1,
#          'Stone': 1,
#          'Garland': 2,
#          'Wingo': 1,
#          'Kendre': 1,
#          'Alston': 1,
#          'Jamison': 2,
#          'Childress': 2,
#          'Burdge': 1,
#          'Shane': 7,
#          'Brandon': 19,
#          'Jones': 12,
#          'Rapp': 1,
#          'Fowler': 1,
#          'White': 5,
#          'Tyrel': 1,
#          'Vick': 1,
#          'Ellis': 2,
#          'Gary': 10,
#          'Page': 2,
#          'Enoch': 1,
#          'Gaver': 1,
#          'Conley': 1,
#          'Healy': 1,
#          'Denzel': 1,
#          'Devin': 5,
#          'Gates': 2,
#          'Stephen': 10,
#          'Snyder': 2,
#          'Walter': 4,
#          'Dunham': 1,
#          'Lorenza': 1,
#          'Kelly': 1,
#          'Terrazas': 1,
#          'Tassinari': 1,
#          'Deanne': 1,
#          'Choate': 1,
#          'Adrian': 4,
#          'Solis': 1,
#          'Kendrick': 1,
#          'Jamalis': 1,
#          'Neil': 3,
#          'Seifert': 1,
#          'Megan': 1,
#          'Hockaday': 1,
#          'Harvey': 1,
#          'Oates': 1,
#          'Angelo': 3,
#          'West': 3,
#          'Rooker': 1,
#          'Byron': 1,
#          'Babb': 1,
#          'Anderson': 12,
#          'Benjamin': 5,
#          'Quezada': 2,
#          'Mya': 1,
#          'Shawn': 6,
#          'Clyde': 3,
#          'Darrin': 3,
#          'Langford': 1,
#          'Hicks': 5,
#          'Eric': 16,
#          'Rutledge': 1,
#          'Prevatt': 1,
#          'Justus': 1,
#          'Howell': 1,
#          'Ethan': 3,
#          'Noll': 1,
#          'Ken': 1,
#          'Cockerel': 1,
#          'Hanna': 1,
#          'Myers': 2,
#          'Tyrell': 1,
#          'Larsen': 1,
#          'Erick': 2,
#          'Faith': 1,
#          'Dexter': 2,
#          'Pernell': 1,
#          'Bethea': 1,
#          'Weber': 2,
#          'Gordon': 2,
#          'Kimbrell': 1,
#          'Don': 5,
#          'Jess': 1,
#          'Leipold': 1,
#          'Cresencio': 1,
#          'Corona': 1,
#          'Mack': 2,
#          'Dale': 4,
#          'Weaver': 1,
#          'Colby': 2,
#          'Finley': 1,
#          'Tevin': 1,
#          'Barkley': 1,
#          'Dante': 2,
#          'Noble': 2,
#          'Frank': 4,
#          'Shephard': 1,
#          'Mark': 20,
#          'W.': 3,
#          'Adair': 1,
#          'Watson': 3,
#          'Flores': 5,
#          'Rodolfo': 1,
#          'Velazquez': 1,
#          'Kemp': 1,
#          'Elias': 2,
#          'Cavazos': 1,
#          'Thaddeus': 2,
#          'McCarroll': 1,
#          'Erik': 3,
#          'Tellez': 1,
#          'Grover': 1,
#          'Foster': 2,
#          'Dana': 3,
#          'Hlavinka': 1,
#          'Santos': 2,
#          'Cortez': 2,
#          'Wolfe': 1,
#          'Covarrubias': 1,
#          'Kimber': 1,
#          'Key': 1,
#          'Luis': 7,
#          'Chapman': 1,
#          'Carlos': 12,
#          'Saavedra': 1,
#          'Ramirez': 6,
#          'Efraim': 1,
#          'Reginald': 3,
#          'McGregor': 1,
#          'Lue': 1,
#          'Vang': 1,
#          'Valadez': 1,
#          'Potts': 1,
#          'Hector': 5,
#          'Morejon': 1,
#          'Karen': 1,
#          'Janks': 1,
#          'Cecil': 1,
#          'Hawkins': 3,
#          'Timmie': 1,
#          'Collins': 3,
#          'Jamal': 5,
#          'Dye': 1,
#          'Felix': 2,
#          'Davis': 13,
#          'Billy': 5,
#          'Albert': 5,
#          'Hanson': 1,
#          'Genova': 1,
#          'Terrance': 1,
#          'Kellom': 1,
#          'Jared': 1,
#          'Green': 5,
#          'Deysie': 1,
#          'Chavez-Diaz': 1,
#          'Alexia': 1,
#          'Christian': 9,
#          'Adkins': 1,
#          'Acree': 1,
#          'Fridoon': 1,
#          'Zalbeg': 1,
#          'Nehad': 1,
#          'Emmanuel': 1,
#          'Sanchez': 7,
#          'Mathena': 1,
#          'Kevin': 16,
#          'Vance': 1,
#          'Norton': 2,
#          'Elton': 1,
#          'Nadir': 1,
#          'Soofi': 1,
#          'Grimm': 1,
#          'Asher': 1,
#          'Roark': 1,
#          'Cook': 2,
#          'Brendon': 1,
#          'Thong': 1,
#          'Kien': 1,
#          'Ma': 2,
#          'A.': 17,
#          'Frost': 1,
#          'Nephi': 2,
#          'Arriguin': 1,
#          'Shaun': 2,
#          'Schwalm': 1,
#          'Dedrick': 1,
#          'Sam': 3,
#          'Cunningham': 1,
#          'Lionel': 4,
#          'Lorenzo': 4,
#          'Young': 4,
#          'Kelvin': 1,
#          'Goldston': 1,
#          'Way': 1,
#          "D'Angelo": 1,
#          'Stallworth': 1,
#          'Zalonka': 1,
#          'Alec': 1,
#          'Ouzounian': 1,
#          'Sean': 6,
#          'Pelletier': 1,
#          'Cary': 1,
#          'Farrar': 1,
#          'Matt': 2,
#          'Coates': 1,
#          'Ronell': 1,
#          'Wade': 3,
#          'Dennis': 8,
#          'Fiel': 1,
#          'Austin': 6,
#          'Goodner': 1,
#          'Timothy': 12,
#          'Alfredo': 1,
#          'Rials-Torres': 1,
#          'McIntosh': 1,
#          'Gaines': 3,
#          'Gomez': 5,
#          'Colley': 1,
#          'Chrislon': 1,
#          'Talbott': 1,
#          'Nikki': 1,
#          'Jo': 2,
#          'Burtsfield': 1,
#          'Wheeler': 1,
#          'Alejandro': 5,
#          'Gandara': 1,
#          'Javoris': 1,
#          'Cooper': 1,
#          'Elvin': 1,
#          'Lowery': 1,
#          'Caso': 1,
#          'Horn': 1,
#          'Cassandra': 1,
#          'Bolin': 1,
#          'Briggs': 3,
#          'Millard': 2,
#          'Tallant': 1,
#          'Dalton': 2,
#          'Branch': 2,
#          'McAllister': 1,
#          'Garrett': 1,
#          'Sandeno': 1,
#          'Feras': 1,
#          'Morad': 1,
#          'Simon': 2,
#          'Hubble': 1,
#          'Darrell': 3,
#          'Morgan': 5,
#          'Strong': 1,
#          'Dothard': 1,
#          'Kyle': 8,
#          'Baker': 6,
#          'Nehemiah': 1,
#          'Fischer': 2,
#          'Box': 1,
#          'Ebin': 1,
#          'Proctor': 1,
#          'Tirado': 1,
#          'Rivera': 3,
#          'Bushey': 1,
#          'Ladd': 1,
#          'Usaamah': 1,
#          'Rahim': 1,
#          'Kamal': 1,
#          'Dajani': 1,
#          'Garza': 3,
#          'Rudy': 1,
#          'Baca': 1,
#          'Edelmiro': 1,
#          'Ronald': 7,
#          'Neal': 1,
#          'Jesus': 6,
#          'Christie': 1,
#          'Cathers': 1,
#          'Demouria': 1,
#          'Hogg': 1,
#          'Smillie': 1,
#          'Campos': 1,
#          'Fernandez': 2,
#          'Nevels': 1,
#          'Damien': 2,
#          'McDaniel': 2,
#          'Gene': 5,
#          'Rene': 4,
#          'Warolf': 1,
#          'Linhart': 1,
#          'Greg': 2,
#          'Hartley': 1,
#          'QuanDavier': 1,
#          'Bolinger': 1,
#          'Isiah': 1,
#          'Hampton': 1,
#          'Ziegler': 1,
#          'Fritz': 1,
#          'Severe': 1,
#          'Peralta-Lantigua': 1,
#          'Shelly': 2,
#          'Haendiges': 1,
#          'Deng': 1,
#          'Manyoun': 1,
#          'Boulware': 1,
#          'Zane': 1,
#          'Terryn': 1,
#          'Kris': 2,
#          'DeLeon': 1,
#          'Charboneau': 1,
#          'Wendy': 1,
#          'Chappell': 1,
#          'Lanphier': 1,
#          'Oleg': 1,
#          'Tcherniak': 1,
#          'Laboy': 1,
#          'Trepierre': 1,
#          'Hummons': 1,
#          'Louis': 3,
#          'Atencio': 1,
#          'Alfontish': 1,
#          'Cockerham': 1,
#          'Simental': 1,
#          'Monroe': 1,
#          'Barrett': 1,
#          'Eduardo': 3,
#          'Tyler': 10,
#          'Wicks': 1,
#          'Dyer': 1,
#          'Wilson': 9,
#          'Randall': 4,
#          'Waddel': 1,
#          'Taylor': 7,
#          'Culbertson': 1,
#          'Harrell': 1,
#          'Spencer': 4,
#          'McCain': 1,
#          'Jake': 2,
#          'Vanderburgh': 1,
#          'Cisneros': 2,
#          'Crittenden': 1,
#          'Bellew': 1,
#          'LaPort': 1,
#          'Clay': 2,
#          'Lickteig': 1,
#          'Judson': 1,
#          'Kaleb': 2,
#          'Landon': 2,
#          'Buckley': 1,
#          'Ton': 1,
#          'Nguyen': 1,
#          'Emanuel': 1,
#          'Larosa': 1,
#          'Cesar': 4,
#          'Limon': 1,
#          'Juarez': 4,
#          'Arturo': 3,
#          'Oscar': 4,
#          'Camacho': 1,
#          'Elando': 1,
#          'Malone': 2,
#          'Shannon': 3,
#          'Gaby': 1,
#          'Kawanza': 1,
#          'Beaty': 2,
#          'Bryan': 5,
#          'Bauer': 2,
#          'Deming': 1,
#          'Holt': 2,
#          'Munroe': 1,
#          'Johnny': 3,
#          'Rogers': 5,
#          'Hagen': 1,
#          'Esty-Lennon': 1,
#          'Oliva': 1,
#          'Sarabia': 1,
#          'Berry': 2,
#          'Hendley': 1,
#          'Marcellus': 2,
#          'Jamarcus': 1,
#          'Burley': 1,
#          'Dujanovic': 1,
#          'Graciano': 1,
#          'Tremaine': 1,
#          'Dantzler': 1,
#          'Booth': 1,
#          'Blough': 1,
#          'Westrich': 1,
#          'Dallas': 1,
#          'Shatley': 1,
#          'Rocco': 1,
#          'Palmisano': 1,
#          'Hammonds': 1,
#          'Martice': 1,
#          'Milliner': 1,
#          'Cyrus': 1,
#          'Hurtado': 2,
#          'Javon': 1,
#          'Todora': 1,
#          'Freddie': 1,
#          'Blue': 1,
#          'McSwain': 1,
#          'Maine': 1,
#          'Castaway': 1,
#          'Salvado': 1,
#          'Ellswood': 1,
#          'Lepine': 1,
#          'Benton': 1,
#          'Frederick': 4,
#          'Farmer': 1,
#          'Graham': 3,
#          'Rafael': 3,
#          'Suazo': 1,
#          'Chacarion': 1,
#          'Avant': 1,
#          'Kailing': 1,
#          'Anthonie': 1,
#          'Gonzalez': 10,
#          'Pippin': 1,
#          'Mohammad': 4,
#          'Youssef': 1,
#          'Abdulazeez': 1,
#          'Saige': 1,
#          'Hack': 1,
#          'Pierre': 2,
#          'Gabriel': 3,
#          'Koellner': 1,
#          'Samuel': 5,
#          'Jackie': 2,
#          'Brand': 1,
#          'Darrius': 1,
#          'Roman': 2,
#          'Wheat': 1,
#          'Dewey': 1,
#          'DuBose': 1,
#          'LeBoeuf': 1,
#          'Darren': 4,
#          'Fuller': 2,
#          'Jerrod': 2,
#          'Tyre': 3,
#          'Francisco': 6,
#          'Benitez-Santiago': 1,
#          'Andre': 3,
#          'Dontrell': 2,
#          'Devon': 2,
#          'Guisherd': 1,
#          'Dontae': 1,
#          'L.': 14,
#          'Wolfsteller': 1,
#          'Stortzum': 1,
#          'Robbie': 1,
#          'Edison': 1,
#          'Tamala': 1,
#          'Satre': 1,
#          'Seth': 1,
#          'Raines': 1,
#          'Gerston': 1,
#          'Olmstead': 1,
#          'Roger': 5,
#          'Braswell': 1,
#          'Keith': 14,
#          'Khari': 1,
#          'Westly': 1,
#          'Zachary': 2,
#          'Hammond': 1,
#          'Milliken': 1,
#          'Jean': 3,
#          'Falgout': 1,
#          'Forgy': 1,
#          'Perkins': 4,
#          'Vrenon': 1,
#          'Philip': 5,
#          'Vallejo': 2,
#          'Lotari': 1,
#          'Romero': 2,
#          'Molina': 1,
#          'Hatch': 1,
#          'Armando': 4,
#          'Serrano': 1,
#          'Virgil': 1,
#          'Reynolds': 2,
#          'Clements': 1,
#          'Malave': 1,
#          'Franklin': 1,
#          'Short': 1,
#          'Ruble': 1,
#          'Avila': 1,
#          'Darius': 4,
#          'Graves': 1,
#          'Dattilo': 1,
#          'Dieringer': 1,
#          'Keshawn': 1,
#          'Dominique': 2,
#          'Hargrove': 1,
#          'Vincente': 1,
#          'Montano': 2,
#          'Galaviz': 1,
#          'Gustavo': 2,
#          'Ponce-Galon': 1,
#          'Bertram': 1,
#          'Abel': 1,
#          'Correa': 1,
#          'Marchese': 1,
#          'Keckhafer': 1,
#          'Tsombe': 1,
#          'Clark': 9,
#          'Derrick': 2,
#          'Hunt': 1,
#          'Shamir': 1,
#          'Terrel': 1,
#          'Palmer': 2,
#          'Wilkes': 1,
#          'Tompkins': 2,
#          'Edrian': 1,
#          'Casey': 3,
#          'George': 9,
#          'Alarcon': 1,
#          'Hughes': 1,
#          'Shull': 1,
#          'Nathaniel': 4,
#          'Wilks': 1,
#          'Redel': 1,
#          'Tyree': 2,
#          'Sorriano': 1,
#          'Asshams': 1,
#          'Pharoah': 1,
#          'Manley': 1,
#          'Unsworth': 1,
#          'Jonathon': 1,
#          'Pope': 1,
#          'Castillo': 1,
#          'Steven': 13,
#          'B.': 5,
#          'Jacquez': 1,
#          'Mansur': 1,
#          'Ball-Bey': 1,
#          'Deviere': 1,
#          'Ernel': 1,
#          'Ransom': 1,
#          'Hale': 2,
#          'Gerken': 1,
#          'Jeffory': 1,
#          'Tevis': 1,
#          'Raul': 3,
#          'Herrera': 4,
#          'Timmy': 1,
#          'Walling': 1,
#          'S.': 6,
#          'Rushton': 1,
#          'Schneider': 1,
#          'Faison': 2,
#          'Alderman': 1,
#          'Garner': 1,
#          'Henry': 10,
#          'Compo': 1,
#          'Troledge': 1,
#          'Norris': 2,
#          'Snider': 1,
#          'Marvin': 4,
#          'Maestas': 1,
#          'Curtis': 4,
#          'Tomlinson': 1,
#          'Rudolph': 2,
#          'Arroliga': 1,
#          'Dodd': 1,
#          'Pickard': 1,
#          'Lambrose': 1,
#          'Bertrand': 1,
#          'Yonas': 1,
#          'Alehegne': 1,
#          'Hober': 1,
#          'Soriano': 1,
#          'Kumi': 1,
#          'Dial': 2,
#          'Cruz': 5,
#          'Jr': 3,
#          'M.': 16,
#          'Rippley': 1,
#          'Cedric': 4,
#          'Maurice': 2,
#          'Shaw': 1,
#          'Arthur': 5,
#          'Bates': 1,
#          'Freddy': 2,
#          'Centeno': 1,
#          'Meyer': 2,
#          'Ramon': 5,
#          'Damiani': 1,
#          'Kelley': 3,
#          'Sully': 1,
#          'Lanier': 1,
#          'Harrison': 2,
#          'Lambert': 4,
#          "La'vante": 1,
#          'Trevon': 2,
#          'Wenceslao': 1,
#          'Delano': 1,
#          'Perry': 5,
#          'India': 2,
#          'Kager': 1,
#          'Yero': 1,
#          'Mohamed': 2,
#          'Ibrahim': 1,
#          'Verrett': 1,
#          'Casimero': 1,
#          'Casillas': 1,
#          'Tristan': 3,
#          'Vent': 1,
#          'Dustin': 2,
#          'Kuik': 1,
#          'Holman': 1,
#          'Perdue': 1,
#          'Chau': 1,
#          'Tian': 1,
#          'Foy': 1,
#          'Wilburly': 1,
#          'Reid': 2,
#          'Eddie': 4,
#          'Tapia': 2,
#          'T.': 5,
#          'Pfleghardt': 1,
#          'Derick': 1,
#          'Jack': 4,
#          'Stevens': 2,
#          'Hammen': 1,
#          ...})

# %%
most_common_name_surname = name_surname_counts.most_common(15)
most_common_name_surname
# Out:
# [('Michael', 82),
#  ('David', 53),
#  ('James', 46),
#  ('Robert', 44),
#  ('Joseph', 43),
#  ('Daniel', 40),
#  ('William', 40),
#  ('John', 36),
#  ('Lee', 36),
#  ('Christopher', 35),
#  ('Richard', 33),
#  ('J.', 30),
#  ('Joshua', 27),
#  ('Anthony', 25),
#  ('Thomas', 23)]

# %%
# Out:
# [('Michael', 82),
#  ('David', 53),
#  ('James', 47),
#  ('Robert', 44),
#  ('Joseph', 43),
#  ('Daniel', 40),
#  ('William', 40),
#  ('Lee', 37),
#  ('John', 36),
#  ('Christopher', 35),
#  ('Richard', 33),
#  ('Smith', 31),
#  ('J.', 30),
#  ('Johnson', 29),
#  ('Joshua', 27)]

# %%
name_df = pd.DataFrame(most_common_name_surname, columns = ['Names or Surnames', 'Frequency'])
name_df
# Out:
#    Names or Surnames  Frequency
# 0            Michael         82
# 1              David         53
# 2              James         46
# 3             Robert         44
# 4             Joseph         43
# 5             Daniel         40
# 6            William         40
# 7               John         36
# 8                Lee         36
# 9        Christopher         35
# 10           Richard         33
# 11                J.         30
# 12            Joshua         27
# 13           Anthony         25
# 14            Thomas         23

# %%
# Out:
#    name_or_surname_most_frequency  frequency
# 0                         Michael         82
# 1                           David         53
# 2                           James         47
# 3                          Robert         44
# 4                          Joseph         43
# 5                          Daniel         40
# 6                         William         40
# 7                             Lee         37
# 8                            John         36
# 9                     Christopher         35
# 10                        Richard         33
# 11                          Smith         31
# 12                             J.         30
# 13                        Johnson         29
# 14                         Joshua         27

# %%
# with pandas_my
ax= name_df.plot(kind='bar', x= 'Names or Surnames',y= 'Frequency', figsize=(14,8))
plt.title('Most Common 15 Name or Surname of killed people')
plt.ylabel('Frequency')
plt.xticks(rotation=45)

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.200, p.get_height() *1.005));

# %%
# with pandas

# %%
# with matplotlib_my
plt.figure(figsize=(12,8))
plt.bar(name_df['Names or Surnames'],name_df['Frequency'])
plt.xlabel('Names or Surnames')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.title('Most Common 15 Name or Surname of killed people')
plt.tight_layout()
for i, v in enumerate(name_df['Frequency']):
    plt.text(i, v, str(v));

# %%
# with matplotlib
